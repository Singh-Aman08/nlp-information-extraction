# %%
# !pip install seqeval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=b986fff94ef0f919140d66a4bca206ebee3285b96000bf613e98d2987fcc2334
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %%
import pandas as pd
import ast
from seqeval.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel(r"/content/drive/MyDrive/Colab Notebooks/cwk_data/cwk_train_data.xlsx")

# %%
df_few_shot = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/Few Shot/result_few_shot_22.csv")

# %%
df['Merged BIO Labels'] = df["Merged BIO Labels"].apply(ast.literal_eval)

# %%
df_few_shot['BIO Labels'] = df_few_shot['BIO Labels'].apply(ast.literal_eval)

# %% [markdown]
# Seqeval

# %%
y_true = []
y_pred = []
for i in range(0,200):
  y_true.append(df['Merged BIO Labels'][i])
  y_pred.append(df_few_shot['BIO Labels'][i])

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          INT       0.51      0.45      0.48      1561
#          OUT       0.42      0.38      0.40      1692
#         PART       0.19      0.24      0.21       687
#
#    micro avg       0.40      0.38      0.39      3940
#    macro avg       0.37      0.36      0.36      3940
# weighted avg       0.42      0.38      0.40      3940

# %% [markdown]
# Sklearn Classification report

# %%
def to_field(label):
    if label =="B-INT" or label =="I-INT":
        return "INT"
    elif label =="B-PART" or label == "I-PART":
        return "PART"
    elif label == "B-OUT" or label =="I-OUT":
        return "OUT"
    else:
        return "O"

# %%
from sklearn.metrics import classification_report

# %%
y_true = []
y_pred = []

for i in range(0,200):
  for t_doc, p_doc in zip(df['Merged BIO Labels'][i], df_few_shot['BIO Labels'][i]):
    y_true.append(to_field(t_doc))
    y_pred.append(to_field(p_doc))

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          INT       0.75      0.38      0.50      4016
#            O       0.87      0.95      0.91     47828
#          OUT       0.74      0.47      0.58      5942
#         PART       0.45      0.42      0.43      1912
#
#     accuracy                           0.85     59698
#    macro avg       0.70      0.55      0.61     59698
# weighted avg       0.84      0.85      0.84     59698
